# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist

# Load the MNIST dataset
(x_train, _), (x_test, _) = mnist.load_data()

# Normalize pixel values to be between 0 and 1
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Flatten the images for the autoencoder
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))

# Define the autoencoder model
encoding_dim = 32  # Size of the encoded representations
input_img = Input(shape=(784,))
encoded = Dense(encoding_dim, activation='relu')(input_img)
decoded = Dense(784, activation='sigmoid')(encoded)

autoencoder = Model(input_img, decoded)

# Compile the autoencoder
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# Train the autoencoder
autoencoder.fit(x_train, x_train, epochs=50, batch_size=256, shuffle=True, validation_data=(x_test, x_test))

# Create a separate encoder model
encoder = Model(input_img, encoded)

# Encode the test images
encoded_imgs = encoder.predict(x_test)

# Decode the encoded images
decoded_imgs = autoencoder.predict(x_test)

# Display original and reconstructed images
n = 10  # Number of digits to display
plt.figure(figsize=(20, 4))
for i in range(n):
    # Original images
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Reconstructed images
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Epoch 1/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.2799 - val_loss: 0.1913
# Epoch 2/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.1716 - val_loss: 0.1532
# Epoch 3/50
# 235/235 [==============================] - 4s 16ms/step - loss: 0.1436 - val_loss: 0.1325
# Epoch 4/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.1276 - val_loss: 0.1200
# Epoch 5/50
# 235/235 [==============================] - 5s 19ms/step - loss: 0.1170 - val_loss: 0.1113
# Epoch 6/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.1098 - val_loss: 0.1057
# Epoch 7/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1051 - val_loss: 0.1018
# Epoch 8/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.1017 - val_loss: 0.0991
# Epoch 9/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0993 - val_loss: 0.0970
# Epoch 10/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0975 - val_loss: 0.0954
# Epoch 11/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0962 - val_loss: 0.0944
# Epoch 12/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0954 - val_loss: 0.0937
# Epoch 13/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0949 - val_loss: 0.0933
# Epoch 14/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0945 - val_loss: 0.0929
# Epoch 15/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0942 - val_loss: 0.0928
# Epoch 16/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0940 - val_loss: 0.0926
# Epoch 17/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0938 - val_loss: 0.0925
# Epoch 18/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0937 - val_loss: 0.0923
# Epoch 19/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0935 - val_loss: 0.0923
# Epoch 20/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0935 - val_loss: 0.0921
# Epoch 21/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0934 - val_loss: 0.0921
# Epoch 22/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0933 - val_loss: 0.0921
# Epoch 23/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0933 - val_loss: 0.0921
# Epoch 24/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0932 - val_loss: 0.0921
# Epoch 25/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0931 - val_loss: 0.0920
# Epoch 26/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0931 - val_loss: 0.0919
# Epoch 27/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0931 - val_loss: 0.0918
# Epoch 28/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0930 - val_loss: 0.0919
# Epoch 29/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0930 - val_loss: 0.0920
# Epoch 30/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 31/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 32/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 33/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 34/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0929 - val_loss: 0.0918
# Epoch 35/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 36/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0929 - val_loss: 0.0917
# Epoch 37/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0928 - val_loss: 0.0918
# Epoch 38/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 39/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0928 - val_loss: 0.0917
# Epoch 40/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 41/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 42/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 43/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 44/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0927 - val_loss: 0.0917
# Epoch 45/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 46/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 47/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 48/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0927 - val_loss: 0.0916
# Epoch 49/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0927 - val_loss: 0.0915
# Epoch 50/50
# 235/235 [==============================] - 2s 8ms/step - loss: 0.0927 - val_loss: 0.0916
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
